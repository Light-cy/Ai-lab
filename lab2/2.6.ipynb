# %%
a=[1,3,5]
b=[2,4,6]
c=a+b
print(c)

d=sorted(c)
print(d)

d.reverse()
print(d)

c[4]=42
print(c)

d.append(10)
print(d)

c.extend([7,8,9])
print(c)
# Out:
# [1, 3, 5, 2, 4, 6]
# [1, 2, 3, 4, 5, 6]
# [6, 5, 4, 3, 2, 1]
# [1, 3, 5, 2, 42, 6]
# [6, 5, 4, 3, 2, 1, 10]
# [1, 3, 5, 2, 42, 6, 7, 8, 9]
